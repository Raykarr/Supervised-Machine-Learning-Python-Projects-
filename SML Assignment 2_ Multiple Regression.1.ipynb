# %% [markdown]
# ## <font color='purple'>SML Assignment 2: Multiple Regression </font>
# ### Kaustubh Raykar
# PRN : 21070126048 <br>
# <break> AIML A3

# %% [markdown]
# <font color='teal'>BIKE DATASET</font>

# %% [markdown]
# ### <font color='teal'>Step 1 : Importing Libraries </font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### <font color='teal'> Step 2: Upload Dataset </font>

# %%
df=pd.read_csv("E:\\4TH SEM NOTES\\datasets\\day.csv")
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0             2  14.110847  18.18125  80.5833  10.749882     331         654
# 1             2  14.902598  17.68695  69.6087  16.652113     131         670
# 2             1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3             1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4             1   9.305237  11.46350  43.6957  12.522300      82        1518
# ..          ...        ...       ...      ...        ...     ...         ...
# 725           2  10.420847  11.33210  65.2917  23.458911     247        1867
# 726           2  10.386653  12.75230  59.0000  10.416557     644        2451
# 727           2  10.386653  12.12000  75.2917   8.333661     159        1182
# 728           1  10.489153  11.58500  48.3333  23.500518     364        1432
# 729           2   8.849153  11.17435  57.7500  10.374682     439        2290
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 725  2114
# 726  3095
# 727  1341
# 728  1796
# 729  2729
#
# [730 rows x 16 columns]

# %% [markdown]
# ### <font color='teal'>Step 3: Data Description </font>

# %%
# Dropping the unnecessary values 
df = df.drop(columns=["instant","season","yr","mnth","temp","holiday","casual"])
df
# Out:
#          dteday  weekday  workingday  weathersit     atemp      hum  \
# 0    01-01-2018        6           0           2  18.18125  80.5833
# 1    02-01-2018        0           0           2  17.68695  69.6087
# 2    03-01-2018        1           1           1   9.47025  43.7273
# 3    04-01-2018        2           1           1  10.60610  59.0435
# 4    05-01-2018        3           1           1  11.46350  43.6957
# ..          ...      ...         ...         ...       ...      ...
# 725  27-12-2019        4           1           2  11.33210  65.2917
# 726  28-12-2019        5           1           2  12.75230  59.0000
# 727  29-12-2019        6           0           2  12.12000  75.2917
# 728  30-12-2019        0           0           1  11.58500  48.3333
# 729  31-12-2019        1           1           2  11.17435  57.7500
#
#      windspeed  registered   cnt
# 0    10.749882         654   985
# 1    16.652113         670   801
# 2    16.636703        1229  1349
# 3    10.739832        1454  1562
# 4    12.522300        1518  1600
# ..         ...         ...   ...
# 725  23.458911        1867  2114
# 726  10.416557        2451  3095
# 727   8.333661        1182  1341
# 728  23.500518        1432  1796
# 729  10.374682        2290  2729
#
# [730 rows x 9 columns]

# %%
#Renaming the columns 
df = df.rename(columns={'dteday': 'date', 'weathersit': 'weather','atemp': 'temperature', 'hum': 'humidity', 'cnt': 'count'})
df
# Out:
#            date  weekday  workingday  weather  temperature  humidity  \
# 0    01-01-2018        6           0        2     18.18125   80.5833
# 1    02-01-2018        0           0        2     17.68695   69.6087
# 2    03-01-2018        1           1        1      9.47025   43.7273
# 3    04-01-2018        2           1        1     10.60610   59.0435
# 4    05-01-2018        3           1        1     11.46350   43.6957
# ..          ...      ...         ...      ...          ...       ...
# 725  27-12-2019        4           1        2     11.33210   65.2917
# 726  28-12-2019        5           1        2     12.75230   59.0000
# 727  29-12-2019        6           0        2     12.12000   75.2917
# 728  30-12-2019        0           0        1     11.58500   48.3333
# 729  31-12-2019        1           1        2     11.17435   57.7500
#
#      windspeed  registered  count
# 0    10.749882         654    985
# 1    16.652113         670    801
# 2    16.636703        1229   1349
# 3    10.739832        1454   1562
# 4    12.522300        1518   1600
# ..         ...         ...    ...
# 725  23.458911        1867   2114
# 726  10.416557        2451   3095
# 727   8.333661        1182   1341
# 728  23.500518        1432   1796
# 729  10.374682        2290   2729
#
# [730 rows x 9 columns]

# %%
#drived column: "date" extract date and rename it to date 
df['date'] = df['date'].apply(lambda x: int(x.split('-')[0]))
df
# Out:
#      date  weekday  workingday  weather  temperature  humidity  windspeed  \
# 0       1        6           0        2     18.18125   80.5833  10.749882
# 1       2        0           0        2     17.68695   69.6087  16.652113
# 2       3        1           1        1      9.47025   43.7273  16.636703
# 3       4        2           1        1     10.60610   59.0435  10.739832
# 4       5        3           1        1     11.46350   43.6957  12.522300
# ..    ...      ...         ...      ...          ...       ...        ...
# 725    27        4           1        2     11.33210   65.2917  23.458911
# 726    28        5           1        2     12.75230   59.0000  10.416557
# 727    29        6           0        2     12.12000   75.2917   8.333661
# 728    30        0           0        1     11.58500   48.3333  23.500518
# 729    31        1           1        2     11.17435   57.7500  10.374682
#
#      registered  count
# 0           654    985
# 1           670    801
# 2          1229   1349
# 3          1454   1562
# 4          1518   1600
# ..          ...    ...
# 725        1867   2114
# 726        2451   3095
# 727        1182   1341
# 728        1432   1796
# 729        2290   2729
#
# [730 rows x 9 columns]

# %%
# Checking head of the dataset
df.head()
# Out:
#    date  weekday  workingday  weather  temperature  humidity  windspeed  \
# 0     1        6           0        2     18.18125   80.5833  10.749882
# 1     2        0           0        2     17.68695   69.6087  16.652113
# 2     3        1           1        1      9.47025   43.7273  16.636703
# 3     4        2           1        1     10.60610   59.0435  10.739832
# 4     5        3           1        1     11.46350   43.6957  12.522300
#
#    registered  count
# 0         654    985
# 1         670    801
# 2        1229   1349
# 3        1454   1562
# 4        1518   1600

# %%
# Checking the shape of df
df.shape
# Out:
# (730, 9)

# %%
# Checking the descriptive information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         730 non-null    int64
#  1   weekday      730 non-null    int64
#  2   workingday   730 non-null    int64
#  3   weather      730 non-null    int64
#  4   temperature  730 non-null    float64
#  5   humidity     730 non-null    float64
#  6   windspeed    730 non-null    float64
#  7   registered   730 non-null    int64
#  8   count        730 non-null    int64
# dtypes: float64(3), int64(6)
# memory usage: 51.5 KB

# %%
#checking the data description
df.describe()
# Out:
#              date     weekday  workingday     weather  temperature  \
# count  730.000000  730.000000  730.000000  730.000000   730.000000
# mean    15.720548    2.997260    0.683562    1.394521    23.726322
# std      8.802278    2.006161    0.465405    0.544807     8.150308
# min      1.000000    0.000000    0.000000    1.000000     3.953480
# 25%      8.000000    1.000000    0.000000    1.000000    16.889713
# 50%     16.000000    3.000000    1.000000    1.000000    24.368225
# 75%     23.000000    5.000000    1.000000    2.000000    30.445775
# max     31.000000    6.000000    1.000000    3.000000    42.044800
#
#          humidity   windspeed   registered        count
# count  730.000000  730.000000   730.000000   730.000000
# mean    62.765175   12.763620  3658.757534  4508.006849
# std     14.237589    5.195841  1559.758728  1936.011647
# min      0.000000    1.500244    20.000000    22.000000
# 25%     52.000000    9.041650  2502.250000  3169.750000
# 50%     62.625000   12.125325  3664.500000  4548.500000
# 75%     72.989575   15.625589  4783.250000  5966.000000
# max     97.250000   34.000021  6946.000000  8714.000000

# %% [markdown]
# ### <font color='teal'>Step 4 : Data Cleaning </font>

# %%
#Check for null values
df.isnull().sum()
#there are no null/missing values
# Out:
# date           0
# weekday        0
# workingday     0
# weather        0
# temperature    0
# humidity       0
# windspeed      0
# registered     0
# count          0
# dtype: int64

# %%
df.dtypes
# Out:
# date             int64
# weekday          int64
# workingday       int64
# weather          int64
# temperature    float64
# humidity       float64
# windspeed      float64
# registered       int64
# count            int64
# dtype: object

# %% [markdown]
# ### <font color='teal'>Step 5: Data Visualisation , EDA </font>

# %%
#plotting heatmap
import seaborn as sns
cor=df.corr()
plt.figure(figsize=(10,5))
sns.heatmap(cor, annot = True)
plt.show()

# %%
sns.jointplot(data=df, x="temperature", y="humidity", hue="weather", palette = "plasma")

# %%
sns.scatterplot(df["registered"], df["count"], hue=df["weather"], style=df['workingday'],palette = "flare")
plt.show()
# Out:
# C:\Users\kaust\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot(
data=df, x="humidity", y="temperature",
col="workingday", hue="registered",
)

# %%
df.columns
# Out:
# Index(['date', 'weekday', 'workingday', 'weather', 'temperature', 'humidity',
#        'windspeed', 'registered', 'count'],
#       dtype='object')

# %% [markdown]
# ### <font color='teal'>Step 7: Splitting the data </font>

# %%
#splitting df two parts
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
# x is independent feature 
x
# Out:
#      date  weekday  workingday  weather  temperature  humidity  windspeed  \
# 0       1        6           0        2     18.18125   80.5833  10.749882
# 1       2        0           0        2     17.68695   69.6087  16.652113
# 2       3        1           1        1      9.47025   43.7273  16.636703
# 3       4        2           1        1     10.60610   59.0435  10.739832
# 4       5        3           1        1     11.46350   43.6957  12.522300
# ..    ...      ...         ...      ...          ...       ...        ...
# 725    27        4           1        2     11.33210   65.2917  23.458911
# 726    28        5           1        2     12.75230   59.0000  10.416557
# 727    29        6           0        2     12.12000   75.2917   8.333661
# 728    30        0           0        1     11.58500   48.3333  23.500518
# 729    31        1           1        2     11.17435   57.7500  10.374682
#
#      registered
# 0           654
# 1           670
# 2          1229
# 3          1454
# 4          1518
# ..          ...
# 725        1867
# 726        2451
# 727        1182
# 728        1432
# 729        2290
#
# [730 rows x 8 columns]

# %%
# y is dependent feature 
y
# Out:
# 0       985
# 1       801
# 2      1349
# 3      1562
# 4      1600
#        ...
# 725    2114
# 726    3095
# 727    1341
# 728    1796
# 729    2729
# Name: count, Length: 730, dtype: int64

# %% [markdown]
# ### <font color='teal'>Step 8 : Split x and y into training and test data set  </font>

# %%
#splitting the data into training and testing
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size = 0.2, random_state=100)

# %%
#x in train testing values in x and y 
#y in train testing values in x and y 
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (584, 8)
# (146, 8)
# (584,)
# (146,)

# %% [markdown]
# ### <font color='teal'>Step 9: Scaling the data  </font>

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()  #StandardScaler: transforming data into particular size
#x_train = pd.DataFrame(scaler.fit_transform(x_train), columns = x_train.columns)
#x_test = pd.DataFrame(scaler.transform(x_test), columns = x_test.columns)

# %%
#x in train testing values in x and y 
#y in train testing values in x and y 
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (584, 8)
# (146, 8)
# (584,)
# (146,)

# %% [markdown]
# ### <font color='teal'>Step 10: Import Regression Model  </font>

# %%
from sklearn.linear_model import LinearRegression
#create the model instance
mlr = LinearRegression()
#fit the model on the training data
mlr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#from sklearn.linear_model import LinearRegression
#mlr = LinearRegression()
#mlr.fit(x_train, y_train)

# %% [markdown]
# ### <font color='teal'>Step 11: Calculating slope and intercept for each factor  </font>

# %%
print("Intercept: ",mlr.intercept_)
print("Coefficients: ")
list(zip(x,mlr.coef_))
# Out:
# Intercept:  399.2493345943112
# Coefficients:
# [('date', -0.17289145108768667),
#  ('weekday', 20.616605489923614),
#  ('workingday', -920.8550053650646),
#  ('weather', -39.989167684980735),
#  ('temperature', 33.87105074490125),
#  ('humidity', -3.2722617474421694),
#  ('windspeed', -5.8337426767534),
#  ('registered', 1.1490901063400474)]

# %% [markdown]
# ### <font color='teal'>Step 12: Predicting Values </font>

# %%
y_pred_mlr = mlr.predict(x_test)
print("Prediction for test set: {}".format(y_pred_mlr))
# Out:
# Prediction for test set: [4647.51486257 6614.56856732 2686.58921017 4918.36427662 5259.97723651
#  3916.94970338 4506.84724372 4863.41283814 5233.09511306 4723.60850925
#  6410.23073624 6585.48479555 3984.71328954 5989.36306263 2605.87846821
#  6868.85691945 4992.65906215 1255.83194596 5601.6341681  5246.62460802
#  7914.05696892 2488.51627088 5479.23340781 1775.55948299 4110.90226676
#  4618.72303832 7767.25049032 4971.28457242 7260.00773743 4239.05575001
#  7012.50714339 7513.78413535 4943.81564732 4222.16782014 1515.93501501
#  3893.05759576 4102.09409106 6023.43151465 1647.10548001 4613.63608286
#  4690.32286544 2830.89406854 5879.58170558 4266.79242329 5093.97621408
#  6856.1270082  1719.76355855 4258.18463976 5477.69865202 2491.62003042
#  7304.39791002 4975.38086012 5237.2568807  6869.79994893 1911.70783717
#  6140.7411446  4361.42179124 4661.7818564  2726.0913937  5743.51656994
#  4476.87952047 4185.71202434 1528.14850136 4811.13113763 5979.01762583
#  4625.55550632 7906.25673735 5700.31606238 4406.72125991 7571.64377034
#  1179.94101745 4818.7039606  7788.84631828 5155.28485925 4369.51945006
#  4246.20631001 3228.2308288  7285.65395006 4719.87770613 4984.64633866
#  5021.71758498 5945.31614006 3915.84165369 3954.42405221 7320.60424952
#  3983.19318079 6505.73087007 3347.48478876 3466.97256672 3315.9198375
#  1074.52570358 4560.2606372  5968.94152454 3197.03259113 3949.5898523
#  7902.99031213 5797.18890419  -94.12771816 4328.83769556 1601.87633831
#  5392.56604698 4784.34648632 1866.27050605 4531.56349326 5570.14431892
#  3536.84424433 2482.77200904 3814.54775594 4074.02572841 1244.08451351
#  3123.13735235 5258.72127628 4799.61090486 6324.39225503 3918.1408153
#  3485.96256876 4164.80963641 1471.40070595 3416.39438104 4944.31478777
#  7950.69894942 4152.2717837  4290.17819347 5862.92327203 4997.04978176
#  3854.95849981 7767.13887665 1700.44312187 4889.97035738 6156.51644826
#  2585.97921011 4838.22530371  421.44346198 4395.99168918 7538.22024416
#  3054.49099065 1978.37376023 1882.55181361 4229.89907975 5082.46632007
#  3754.36085494 4378.66019289 3589.64347443 1253.10436988 4502.90592593
#   883.56358837]

# %%
mlr_diff = pd.DataFrame({'Actual value': y_test,'Predicted value': y_pred_mlr})
mlr_diff.head(10)
# Out:
#      Actual value  Predicted value
# 184          6043      4647.514863
# 535          6211      6614.568567
# 299          2659      2686.589210
# 221          4780      4918.364277
# 152          4968      5259.977237
# 404          3830      3916.949703
# 198          4458      4506.847244
# 171          4835      4863.412838
# 512          6043      5233.095113
# 200          4332      4723.608509

# %% [markdown]
# ### <font color='teal'> Step 13: Calculating R2E, MAE, MSE, RMSE </font>

# %%
from sklearn import metrics

meanAbErr = metrics.mean_absolute_error(y_test, y_pred_mlr)
meanSqErr = metrics.mean_squared_error(y_test, y_pred_mlr) 
rootMeanSqErr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_mlr)) 
print('R_squared: {:.2f}'.format(mlr.score(x,y)*100)) 
print('Mean Absolute Error:', meanAbErr) 
print('Mean Square Error:', meanSqErr)
print('Root Mean Square Error:', rootMeanSqErr)
# Out:
# R_squared: 96.31
# Mean Absolute Error: 297.3399887666348
# Mean Square Error: 176361.43626864647
# Root Mean Square Error: 419.9540882866203

# %% [markdown]
# ### <font color='teal'>Step 14: Plotting values using a scatter plot </font>

# %%
plt.scatter(y_test, y_pred_mlr, marker='*', color='red', label='predicted')
plt.scatter(y_test, y_test, marker='+', color='blue', label='actual')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs. Predicted')
plt.legend()

# %% [markdown]
# ## THANK YOU
